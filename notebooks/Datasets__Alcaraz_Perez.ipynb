# %% [markdown]
# # Datasets potenciales

# %% [markdown]
# Autor: Yojan Andrés Alcaraz Pérez

# %%
import pandas as pd

# %% [markdown]
# ## Dataset 1

# %%
hotel_res = pd.read_csv("/workspaces/DSCH-Desafios/data/Hotel Reservations.csv")

# %%
hotel_res.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %%
hotel_res.shape
# Out:
# (36275, 19)

# %% [markdown]
# ## Dataset 2

# %%
hurto = pd.read_csv("/workspaces/DSCH-Desafios/data/hurto_a_persona_transporte_publico.csv", sep = ';')
# Out:
# /tmp/ipykernel_28943/3908614431.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   hurto = pd.read_csv("/workspaces/DSCH-Desafios/data/hurto_a_persona_transporte_publico.csv", sep = ';')

# %%
hurto.head()
# Out:
#                      fecha_hecho  cantidad   latitud   longitud    sexo  edad  \
# 0  2017-01-01T16:00:00.000-05:00       1.0  6.276236 -75.553533  Hombre    37
# 1  2017-01-01T16:00:00.000-05:00       1.0  6.219071 -75.602996   Mujer    29
# 2  2017-01-01T16:00:00.000-05:00       1.0  6.219071 -75.602996   Mujer    29
# 3  2017-01-02T10:30:00.000-05:00       1.0  6.242754 -75.548365  Hombre    36
# 4  2017-01-02T10:30:00.000-05:00       1.0  6.242754 -75.548365  Hombre    36
#
#              estado_civil grupo_actor actividad_delictiva parentesco  ...  \
# 0               Casado(a)    Sin dato            Sin dato   Sin dato  ...
# 1  Unión marital de hecho    Sin dato            Sin dato   Sin dato  ...
# 2  Unión marital de hecho    Sin dato            Sin dato   Sin dato  ...
# 3               Casado(a)    Sin dato            Sin dato   Sin dato  ...
# 4               Casado(a)    Sin dato            Sin dato   Sin dato  ...
#
# ...

# %% [markdown]
# ## Dataset 3

# %%
hipertension = pd.read_csv("/workspaces/DSCH-Desafios/data/hypertension_data.csv")

# %%
hipertension.shape
# Out:
# (26083, 14)

# %%
hipertension.head()
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  57.0  1.0   3       145   233    1        0      150      0      2.3
# 1  64.0  0.0   2       130   250    0        1      187      0      3.5
# 2  52.0  1.0   1       130   204    0        0      172      0      1.4
# 3  56.0  0.0   1       120   236    0        1      178      0      0.8
# 4  66.0  0.0   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1
